# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re

# %%
rent = pd.read_csv('../data/Apartment_List_Rent_Estimates_State_2021_11.csv')

# %%
rent.head(5)
# Out:
#   State_Name  FIPS_Code  Population Bedroom_Size  2017_01  2017_02  2017_03  \
# 0    Alabama          1     4864680     _Overall    829.0    835.0    836.0
# 1    Alabama          1     4864680      _Studio    635.0    639.0    640.0
# 2    Alabama          1     4864680          1br    644.0    649.0    650.0
# 3    Alabama          1     4864680          2br    791.0    797.0    798.0
# 4    Alabama          1     4864680          3br    961.0    968.0    969.0
#
#    2017_04  2017_05  2017_06  ...  2021_02  2021_03  2021_04  2021_05  \
# 0    835.0    839.0    839.0  ...    925.0    932.0    942.0    964.0
# 1    639.0    642.0    642.0  ...    708.0    714.0    721.0    738.0
# 2    649.0    652.0    652.0  ...    719.0    724.0    732.0    749.0
# 3    797.0    801.0    801.0  ...    883.0    890.0    899.0    920.0
# 4    968.0    972.0    973.0  ...   1072.0   1081.0   1092.0   1117.0
#
#    2021_06  2021_07  2021_08  2021_09  2021_10  2021_11
# ...

# %%
rent.tail()
# Out:
#     State_Name  FIPS_Code  Population Bedroom_Size  2017_01  2017_02  2017_03  \
# 283    Wyoming         56      581836      _Studio    673.0    690.0    693.0
# 284    Wyoming         56      581836          1br    640.0    656.0    659.0
# 285    Wyoming         56      581836          2br    798.0    818.0    822.0
# 286    Wyoming         56      581836          3br   1063.0   1090.0   1094.0
# 287    Wyoming         56      581836          4br   1307.0   1340.0   1345.0
#
#      2017_04  2017_05  2017_06  ...  2021_02  2021_03  2021_04  2021_05  \
# 283    672.0    658.0    668.0  ...    649.0    655.0    682.0    708.0
# 284    639.0    625.0    635.0  ...    617.0    623.0    648.0    673.0
# 285    796.0    779.0    791.0  ...    769.0    776.0    808.0    838.0
# 286   1061.0   1038.0   1054.0  ...   1025.0   1034.0   1076.0   1117.0
# 287   1304.0   1276.0   1296.0  ...   1260.0   1271.0   1323.0   1373.0
#
#      2021_06  2021_07  2021_08  2021_09  2021_10  2021_11
# ...

# %%
rent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 63 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State_Name    288 non-null    object
#  1   FIPS_Code     288 non-null    int64
#  2   Population    288 non-null    int64
#  3   Bedroom_Size  288 non-null    object
#  4   2017_01       288 non-null    float64
#  5   2017_02       288 non-null    float64
#  6   2017_03       288 non-null    float64
#  7   2017_04       288 non-null    float64
#  8   2017_05       288 non-null    float64
#  9   2017_06       288 non-null    float64
#  10  2017_07       288 non-null    float64
#  11  2017_08       288 non-null    float64
#  12  2017_09       288 non-null    float64
#  13  2017_10       288 non-null    float64
#  14  2017_11       288 non-null    float64
#  15  2017_12       288 non-null    float64
#  16  2018_01       288 non-null    float64
# ...

# %%
rent.shape
# Out:
# (288, 63)

# %%
rent2 = rent.drop(columns = ['2021_01','2021_02','2021_03','2021_04','2021_05',
                     '2021_06','2021_07','2021_08','2021_09','2021_10','2021_11'])

# %%
rent2.shape
# Out:
# (288, 52)

# %%
rent2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State_Name    288 non-null    object
#  1   FIPS_Code     288 non-null    int64
#  2   Population    288 non-null    int64
#  3   Bedroom_Size  288 non-null    object
#  4   2017_01       288 non-null    float64
#  5   2017_02       288 non-null    float64
#  6   2017_03       288 non-null    float64
#  7   2017_04       288 non-null    float64
#  8   2017_05       288 non-null    float64
#  9   2017_06       288 non-null    float64
#  10  2017_07       288 non-null    float64
#  11  2017_08       288 non-null    float64
#  12  2017_09       288 non-null    float64
#  13  2017_10       288 non-null    float64
#  14  2017_11       288 non-null    float64
#  15  2017_12       288 non-null    float64
#  16  2018_01       288 non-null    float64
# ...

# %%
rent2
# Out:
#     State_Name  FIPS_Code  Population Bedroom_Size  2017_01  2017_02  2017_03  \
# 0      Alabama          1     4864680     _Overall    829.0    835.0    836.0
# 1      Alabama          1     4864680      _Studio    635.0    639.0    640.0
# 2      Alabama          1     4864680          1br    644.0    649.0    650.0
# 3      Alabama          1     4864680          2br    791.0    797.0    798.0
# 4      Alabama          1     4864680          3br    961.0    968.0    969.0
# ..         ...        ...         ...          ...      ...      ...      ...
# 283    Wyoming         56      581836      _Studio    673.0    690.0    693.0
# 284    Wyoming         56      581836          1br    640.0    656.0    659.0
# 285    Wyoming         56      581836          2br    798.0    818.0    822.0
# 286    Wyoming         56      581836          3br   1063.0   1090.0   1094.0
# 287    Wyoming         56      581836          4br   1307.0   1340.0   1345.0
#
# ...

# %%
rent2.State_Name.value_counts().head().sort_values()
# Out:
# Colorado        6
# Michigan        6
# Iowa            6
# Missouri        6
# Pennsylvania    6
# Name: State_Name, dtype: int64
